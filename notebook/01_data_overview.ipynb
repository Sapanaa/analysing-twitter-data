# %%
import pandas as pd
import numpy as np

# %%
url = "https://assets.datacamp.com/production/repositories/2161/datasets/43d85d27d293323c1a4effec25717d0c2eb43169/data-science-hashtags.csv"
df2 = pd.read_csv(url, low_memory=False)

# %%
df2.head()
# Out:
#    contributors coordinates                      created_at  \
# 0           NaN         NaN  Thu Mar 01 07:02:41 +0000 2018
# 1           NaN         NaN  Thu Mar 01 07:57:08 +0000 2018
# 2           NaN         NaN  Thu Mar 01 08:09:02 +0000 2018
# 3           NaN         NaN  Thu Mar 01 09:22:21 +0000 2018
# 4           NaN         NaN  Thu Mar 01 12:04:04 +0000 2018
#
#   display_text_range                                           entities  \
# 0                NaN  {'hashtags': [{'text': 'python', 'indices': [8...
# 1                NaN  {'hashtags': [{'text': 'Software', 'indices': ...
# 2                NaN  {'hashtags': [{'text': 'python', 'indices': [0...
# 3           [0, 115]  {'hashtags': [{'text': 'data', 'indices': [66,...
# 4           [0, 100]  {'hashtags': [{'text': 'python', 'indices': [4...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 43 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   contributors                               0 non-null      float64
#  1   coordinates                                3 non-null      object
#  2   created_at                                 1169 non-null   object
#  3   display_text_range                         225 non-null    object
#  4   entities                                   1169 non-null   object
#  5   extended_entities                          163 non-null    object
#  6   extended_tweet                             163 non-null    object
#  7   extended_tweet-full_text                   163 non-null    object
#  8   favorite_count                             1169 non-null   int64
#  9   favorited                                  1169 non-null   bool
# ...

# %%
df = df2.copy()

# %%
df = df.drop(['contributors','coordinates'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 41 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   created_at                                 1169 non-null   object
#  1   display_text_range                         225 non-null    object
#  2   entities                                   1169 non-null   object
#  3   extended_entities                          163 non-null    object
#  4   extended_tweet                             163 non-null    object
#  5   extended_tweet-full_text                   163 non-null    object
#  6   favorite_count                             1169 non-null   int64
#  7   favorited                                  1169 non-null   bool
#  8   filter_level                               1169 non-null   object
#  9   geo                                        3 non-null      object
# ...

# %%
df['text'].values[0:5]
# Out:
# array(['RT @pythonbot_: Learning Penetration Testing With Python  https://t.co/seRRrwhvwn #python #programming #pythonbot_',
#        'RT @I_m_ranjeet: Is Language Agnosticism the Future of #Software #Development? Know Here ?  https://t.co/xMWh4zGclc #Java #PHP #Javascript…',
#        "#python goes to #school for #beginner #scientist and #engineer. It's so easy to find solution for #equation in form… https://t.co/JM8jGllwxk",
#        'Easy way to set Oracle Active Dataguard\n☞ https://t.co/sPjMJE2Pfl\n#data #science #python #tableau #sql #R\nHyWotyN_M https://t.co/S2RvAxcyRH',
#        'Python 3 for Beginners\n☞ https://t.co/va5XaJXVOy\n#python #programming #development #course\nSJ4KjeVOM https://t.co/r94xugsd4A'],
#       dtype=object)

# %%
python = df['text'].str.contains('#python', case = False)

# %%
print("Proportion of #python tweets:", np.sum(python) / df.shape[0])
# Out:
# Proportion of #python tweets: 0.42771599657827203

# %% [markdown]
# Relevant text may not only be in the main text field of the tweet. It may also be in the extended_tweet, the retweeted_status, or the quoted_status. We need to check all of these fields to make sure we've accounted for all the of the relevant text

# %%
def check_word_in_tweet(word, data):
    """Checks if a word is in a Twitter dataset's text. 
    Checks text and extended tweet (140+ character tweets) for tweets,
    retweets and quoted tweets.
    Returns a logical pandas Series.
    """
    contains_column = data['text'].str.contains(word, case = False)
    contains_column |= data['extended_tweet-full_text'].str.contains(word, case = False)
    contains_column |= data['quoted_status-text'].str.contains(word, case = False) 
    contains_column |= data['quoted_status-extended_tweet-full_text'].str.contains(word, case = False) 
    contains_column |= data['retweeted_status-text'].str.contains(word, case = False) 
    contains_column |= data['retweeted_status-extended_tweet-full_text'].str.contains(word, case = False)
    return contains_column

# %%
python = check_word_in_tweet("#python", df)
rstats = check_word_in_tweet("#rstats", df)

# Print proportion of tweets mentioning #python
print("Proportion of #python tweets:", np.sum(python) / df.shape[0])

# Print proportion of tweets mentioning #rstats
print("Proportion of #rstats tweets:", np.sum(rstats) / df.shape[0])
# Out:
# Proportion of #python tweets: 0.5680068434559452
# Proportion of #rstats tweets: 0.4679213002566296

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
# Out:
# C:\Users\sapan\AppData\Local\Temp\ipykernel_28328\329245698.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.set_index('created_at', inplace = True)

# %% [markdown]
# Only after setting the created+at as an index we can use the `resample` method

# %%
df.head()
# Out:
#                           display_text_range  \
# created_at
# 2018-03-01 07:02:41+00:00                NaN
# 2018-03-01 07:57:08+00:00                NaN
# 2018-03-01 08:09:02+00:00                NaN
# 2018-03-01 09:22:21+00:00           [0, 115]
# 2018-03-01 12:04:04+00:00           [0, 100]
#
#                                                                     entities  \
# created_at
# 2018-03-01 07:02:41+00:00  {'hashtags': [{'text': 'python', 'indices': [8...
# 2018-03-01 07:57:08+00:00  {'hashtags': [{'text': 'Software', 'indices': ...
# 2018-03-01 08:09:02+00:00  {'hashtags': [{'text': 'python', 'indices': [0...
# 2018-03-01 09:22:21+00:00  {'hashtags': [{'text': 'data', 'indices': [66,...
# 2018-03-01 12:04:04+00:00  {'hashtags': [{'text': 'python', 'indices': [4...
#
#                                                            extended_entities  \
# created_at
# 2018-03-01 07:02:41+00:00                                                NaN
# ...

# %%
# Create a python column
df['python'] = check_word_in_tweet("#python", df)

# Create an rstats column
df['rstats'] = check_word_in_tweet("#rstats", df)

# %%
import matplotlib.pyplot as plt
#  Average of python column by day
mean_python = df['python'].resample('1 d').mean()

# Average of rstats column by day
mean_rstats = df['rstats'].resample('1 d').mean()

# Plot mean python/rstats by day
plt.plot(mean_python.index.day, mean_python, color = 'green')
plt.plot(mean_rstats.index.day, mean_rstats, color = 'blue')

# Add labels and show
plt.xlabel('Day'); plt.ylabel('Frequency')
plt.title('Language mentions over time')
plt.legend(('#python', '#rstats'))
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# VADER SentimentIntensityAnalyzer()
# - Part of Natural Language Toolkit (nltk)
# - Good for short texts like tweetsMeasures sentiment of particular words (e.g. angry, happy)
# - Also considers sentiment of emoji (😀) and capitalization(Nice vs NICE)

# %%
import nltk
nltk.download('vader_lexicon')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
sentiment_scores = df['text'].apply(sid.polarity_scores)
sentiment = sentiment_scores.apply(lambda x: x['compound'])

# %%
# Print out the text of a positive tweet
print(df[sentiment > 0.6]['text'].values[0])

# Print out the text of a negative tweet
print(df[sentiment < -0.6]['text'].values[0])

# Generate average sentiment scores for #python
sentiment_py = sentiment[ check_word_in_tweet('#python', df) ].resample('1 d').mean()

# Generate average sentiment scores for #rstats
sentiment_r = sentiment[ check_word_in_tweet('#rstats', df) ].resample('1 d').mean()
# Out:
# #python goes to #school for #beginner #scientist and #engineer. It's so easy to find solution for #equation in form… https://t.co/JM8jGllwxk
# PythonWeekly: one-pixel-attack-keras - Keras reimplementation of "One pixel attack for fooling deep neural networks… https://t.co/LYcIh17Gnr

# %%
plt.plot(sentiment_py.index.day, sentiment_py, color = 'green')

plt.plot(sentiment_r.index.day, sentiment_r, color = 'blue')

plt.xlabel('Day')
plt.ylabel('Sentiment')
plt.title('Sentiment of data science languages')
plt.legend(('#python', '#rstats'))
plt.show()

# %% [markdown]
# - Both #python and #rstats maintain mostly positive sentiment throughout the period.
# - Sentiment values generally stay above zero, indicating more positive than negative discussions overall.

# %% [markdown]
# ---

# %% [markdown]
# ## Twitter Networks

# %%
# Import networkx
import networkx as nx

# Create retweet network from edgelist
G_rt = nx.from_pandas_edgelist(
    df,
    source = 'user-screen_name', 
    target = 'retweeted_status-user-screen_name',
    create_using = nx.DiGraph())
    
# Print the number of nodes
print('Nodes in RT network:', len(G_rt.nodes()))

# Print the number of edges
print('Edges in RT network:', len(G_rt.edges()))
# Out:
# Nodes in RT network: 1123
# Edges in RT network: 951

# %%
#pip install networkx
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 660.6 kB/s eta 0:00:04
#    ------------ --------------------------- 0.6/2.1 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 14.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import networkx
import networkx as nx

# Create reply network from edgelist
G_reply = nx.from_pandas_edgelist(
    df,
    source = 'user-screen_name', 
    target = 'in_reply_to_screen_name',
    create_using = nx.DiGraph())
    
# Print the number of nodes
print('Nodes in reply network:', len(G_reply.nodes()))

# Print the number of edges
print('Edges in reply network:', len(G_reply.edges()))
# Out:
# Nodes in reply network: 837
# Edges in reply network: 821

# %%
# Create random layout positions
pos = nx.random_layout(G_rt)

# Create size list
sizes = [x[1] for x in G_rt.degree()]

# Draw the network
nx.draw_networkx(G_rt, pos, 
    with_labels = False, 
    node_size = sizes,
    width = 0.1, alpha = 0.7,
    arrowsize = 2, linewidths = 0)

# Turn axis off and show
plt.axis('off'); plt.show()

# %% [markdown]
# - Larger nodes = users with more retweet connections
# - These are influential or highly visible accounts
#
# ➡️ That very large node near the top is the most-retweeted account.

# %% [markdown]
# ---

# %% [markdown]
# Degree centrality measures the proportion of nodes a user is directly connected to.
# - In a Twitter context, connections usually come from:
#     - replies
#     - mentions
#     - retweets

# %%
column_names = ['screen_name', 'degree_centrality']
# Generate in-degree centrality for retweets 
rt_centrality = nx.in_degree_centrality(G_rt)

# Generate in-degree centrality for replies 
reply_centrality = nx.in_degree_centrality(G_reply)

# Store centralities in DataFrame
rt = pd.DataFrame(list(rt_centrality.items()), columns = column_names)
reply = pd.DataFrame(list(reply_centrality.items()), columns = column_names)

# Print first five results in descending order of centrality
print(rt.sort_values('degree_centrality', ascending = False).head())

# Print first five results in descending order of centrality
print(reply.sort_values('degree_centrality', ascending = False).head())
# Out:
#       screen_name  degree_centrality
# 5             NaN           0.299465
# 580     dataandme           0.031194
# 598     Rbloggers           0.024064
# 697  DiffusePrioR           0.018717
# 28       ReactDOM           0.017825
#       screen_name  degree_centrality
# 1             NaN           0.952153
# 331        trello           0.001196
# 177  M3ntally_iLL           0.001196
# 29     TwitterDev           0.001196
# 401    LXIX_Chapo           0.001196

# %% [markdown]
# G_rt → retweet network
#
# G_reply → reply network
#
# Each node = a Twitter user (screen_name)
# Each directed edge = someone retweeted or replied to someone else

# %% [markdown]
# - `dataandme` and `Rbloggers` are highly retweeted
# - Their tweets are being amplified by many users
# - They act as information broadcasters or influencers

# %% [markdown]
# - One central node (likely a main tweet or account) receives most replies
# - Other users are barely replied to
# - This suggests a conversation hub

# %%
# Calculate in-degrees and store in DataFrame
degree_rt = pd.DataFrame(list(G_rt.in_degree()), columns = column_names)
degree_reply = pd.DataFrame(list(G_reply.in_degree()), columns = column_names)

# Merge the two DataFrames on screen name
ratio = degree_rt.merge(degree_reply, on = 'screen_name', suffixes = ('_rt', '_reply'))

# Calculate the ratio
ratio['ratio'] = ratio['degree_centrality_reply'] / ratio['degree_centrality_rt']

# Exclude any tweets with less than 5 retweets
ratio = ratio[ratio['degree_centrality_rt'] >= 5]

# Print out first five with highest ratio
print(ratio.sort_values('ratio', ascending = False).head())
# Out:
#       screen_name  degree_centrality_rt  degree_centrality_reply     ratio
# 5             NaN                   336                      796  2.369048
# 584       rstudio                     5                        1  0.200000
# 16       jrlarsen                     9                        0  0.000000
# 26       ReactDOM                    20                        0  0.000000
# 44   PythonWeekly                     8                        0  0.000000

# %% [markdown]
# | Ratio | Interpretation                               |
# | ----- | -------------------------------------------- |
# | > 1   | Conversation-driven, controversial, or focal |
# | ≈ 1   | Balanced discussion and sharing              |
# | < 1   | Broadcast-focused                            |
# | = 0   | Pure amplification                           |

# %% [markdown]
# “The reply-to-retweet ratio highlights different engagement styles. Users with high ratios generate discussion and replies, while users with low or zero ratios primarily act as broadcasters whose content is shared but not directly engaged with.”

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1169 entries, 2018-03-01 07:02:41+00:00 to 2018-03-31 22:15:54+00:00
# Data columns (total 42 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   display_text_range                         225 non-null    object
#  1   entities                                   1169 non-null   object
#  2   extended_entities                          163 non-null    object
#  3   extended_tweet                             163 non-null    object
#  4   extended_tweet-full_text                   163 non-null    object
#  5   favorite_count                             1169 non-null   int64
#  6   favorited                                  1169 non-null   bool
#  7   filter_level                               1169 non-null   object
#  8   geo                                        3 non-null      object
# ...

# %% [markdown]
# ---
